# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv(r'D:\ML_Files\books.csv')
users = pd.read_csv(r'D:\ML_Files\users.csv')
Ratings = pd.read_csv(r'D:\ML_Files\ratings.csv')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13960\2537652928.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv(r'D:\ML_Files\books.csv')

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
Ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(users.shape)
print(Ratings.shape)
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
Ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# np.int64(0)

# %%
users.duplicated().sum()
# Out:
# np.int64(0)

# %%
Ratings.duplicated().sum()
# Out:
# np.int64(0)

# %%
data = Ratings.merge(books, on='ISBN', how='left')
print('merged shape:', data.shape)
data.head()
# Out:
# merged shape: (1149780, 10)
#    User-ID        ISBN  Book-Rating  \
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6
#
#                                           Book-Title      Book-Author  \
# 0                               Flesh Tones: A Novel       M. J. Rose
# 1                                   Rites of Passage       Judith Rae
# 2                                       The Notebook  Nicholas Sparks
# 3                                     Help!: Level 1    Philip Prowse
# 4  The Amsterdam Connection : Level 4 (Cambridge ...      Sue Leather
#
#   Year-Of-Publication                   Publisher  \
# 0                2002            Ballantine Books
# 1                2001                      Heinle
# 2                1996                Warner Books
# 3                1999  Cambridge University Press
# ...

# %%
# rating distribution
data['Book-Rating'].value_counts().sort_index().plot(kind='bar')
plt.title('Rating distribution')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# numeric summary
data[['Book-Rating']].describe()
# Out:
#         Book-Rating
# count  1.149780e+06
# mean   2.866950e+00
# std    3.854184e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    7.000000e+00
# max    1.000000e+01

# %%
# top users by number of ratings
top_users = Ratings['User-ID'].value_counts().head(20)
top_users.plot(kind='bar', title='Top 20 Most Active Users')
plt.show()

# top books by rating counts
top_books_count = Ratings['ISBN'].value_counts().head(20)
top_books_count = top_books_count.rename_axis('ISBN').reset_index(name='counts')
top_books_count = top_books_count.merge(books[['ISBN','Book-Title','Book-Author']], on='ISBN', how='left')
top_books_count[['Book-Title','counts']].head(20)
# Out:
#                                            Book-Title  counts
# 0                                         Wild Animus    2502
# 1                           The Lovely Bones: A Novel    1295
# 2                                   The Da Vinci Code     883
# 3     Divine Secrets of the Ya-Ya Sisterhood: A Novel     732
# 4                 The Red Tent (Bestselling Backlist)     723
# 5                                     A Painted House     647
# 6                                                 NaN     639
# 7                             The Secret Life of Bees     615
# 8                              Snow Falling on Cedars     614
# 9                                 Angels &amp; Demons     586
# 10  Where the Heart Is (Oprah's Book Club (Paperba...     585
# 11  Harry Potter and the Sorcerer's Stone (Harry P...     571
# 12                         The Pilot's Wife : A Novel     568
# 13                              House of Sand and Fog     552
# ...

# %% [markdown]
# # Popularity based recommendation System

# %%
data.groupby('Book-Title').count()
# Out:
#                                                     User-ID  ISBN  \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...        4     4
#  Always Have Popsicles                                    1     1
#  Apple Magic (The Collector's series)                     1     1
#  Ask Lily (Young Women of Faith: Lily Series, B...        1     1
#  Beyond IBM: Leadership Marketing and Finance f...        1     1
# ...                                                     ...   ...
# Ã?Â?lpiraten.                                             2     2
# Ã?Â?rger mit Produkt X. Roman.                            4     4
# Ã?Â?sterlich leben.                                       1     1
# Ã?Â?stlich der Berge.                                     3     3
# Ã?Â?thique en toc                                         2     2
#
#                                                     Book-Rating  Book-Author  \
# Book-Title
# ...

# %%
number_rating_df=data.groupby('Book-Title').count()['Book-Rating'].reset_index()
number_rating_df.rename(columns={'Book-Rating':'Num-Rating'},inplace =True)
number_rating_df
# Out:
#                                                Book-Title  Num-Rating
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
# [241071 rows x 2 columns]

# %%
data['Book-Rating'] = pd.to_numeric(data['Book-Rating'], errors='coerce')
avg_rating_df = data.groupby('Book-Title')['Book-Rating'].mean().reset_index()
avg_rating_df.rename(columns={'Book-Rating':'Average-Rating'}, inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  Average-Rating
# 0        A Light in the Storm: The Civil War Diary of ...        2.250000
# 1                                   Always Have Popsicles        0.000000
# 2                    Apple Magic (The Collector's series)        0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...        8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...        0.000000
# ...                                                   ...             ...
# 241066                                      Ã?Â?lpiraten.        0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.        5.250000
# 241068                                Ã?Â?sterlich leben.        7.000000
# 241069                              Ã?Â?stlich der Berge.        2.666667
# 241070                                  Ã?Â?thique en toc        4.000000
#
# [241071 rows x 2 columns]

# %%
pop_df=number_rating_df.merge(avg_rating_df,on='Book-Title' )
pop_df
# Out:
#                                                Book-Title  Num-Rating  \
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
#         Average-Rating
# 0             2.250000
# 1             0.000000
# 2             0.000000
# 3             8.000000
# ...

# %% [markdown]
# ### Now we need those books whose num rating is greter then 200

# %%
pop_df[pop_df['Num-Rating']>=200]
# Out:
#                                                Book-Title  Num-Rating  \
# 764                                                  1984         284
# 818                                   1st to Die: A Novel         509
# 1048                                           2nd Chance         356
# 1760                                   A Bend in the Road         346
# 2120                                       A Case of Need         236
# ...                                                   ...         ...
# 234951                                        Wild Animus        2502
# 236334                                      Wish You Well         234
# 236724                                    Without Remorse         203
# 240413  Zen and the Art of Motorcycle Maintenance: An ...         210
# 240860                                \O\" Is for Outlaw"         269
#
#         Average-Rating
# 764           4.454225
# 818           3.575639
# 1048          3.269663
# 1760          3.364162
# ...

# %%
pop_df=pop_df[pop_df['Num-Rating']>=200].sort_values('Average-Rating',ascending=False).head(50)

# %%
pop_df
# Out:
#                                                Book-Title  Num-Rating  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)         428
# 80422        Harry Potter and the Goblet of Fire (Book 4)         387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)         278
# 80426   Harry Potter and the Order of the Phoenix (Boo...         347
# 60582       Ender's Game (Ender Wiggins Saga (Paperback))         249
# 80414    Harry Potter and the Chamber of Secrets (Book 2)         556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...         281
# 187377  The Fellowship of the Ring (The Lord of the Ri...         368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...         575
# 211384     The Two Towers (The Lord of the Rings, Part 2)         260
# 219741                              To Kill a Mockingbird         510
# 183573                                  The Da Vinci Code         898
# ...

# %%
#As one book is more then one time with different ISBN nmbr
pop_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')
# Out:
#                                             Book-Title  Num-Rating  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)         428
# 3         Harry Potter and the Goblet of Fire (Book 4)         387
# 5       Harry Potter and the Sorcerer's Stone (Book 1)         278
# 9    Harry Potter and the Order of the Phoenix (Boo...         347
# 13       Ender's Game (Ender Wiggins Saga (Paperback))         249
# 17    Harry Potter and the Chamber of Secrets (Book 2)         556
# 20   The Hobbit : The Enchanting Prelude to The Lor...         281
# 21   The Fellowship of the Ring (The Lord of the Ri...         368
# 30   Harry Potter and the Sorcerer's Stone (Harry P...         575
# 32      The Two Towers (The Lord of the Rings, Part 2)         260
# 43                               To Kill a Mockingbird         510
# 51                                   The Da Vinci Code         898
# 57                  The Five People You Meet in Heaven         430
# ...

# %%
pop_df=pop_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','Num-Rating','Average-Rating']]

# %%
pop_df
# Out:
#                                             Book-Title          Book-Author  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)        J. K. Rowling
# 3         Harry Potter and the Goblet of Fire (Book 4)        J. K. Rowling
# 5       Harry Potter and the Sorcerer's Stone (Book 1)        J. K. Rowling
# 9    Harry Potter and the Order of the Phoenix (Boo...        J. K. Rowling
# 13       Ender's Game (Ender Wiggins Saga (Paperback))     Orson Scott Card
# 17    Harry Potter and the Chamber of Secrets (Book 2)        J. K. Rowling
# 20   The Hobbit : The Enchanting Prelude to The Lor...       J.R.R. TOLKIEN
# 21   The Fellowship of the Ring (The Lord of the Ri...       J.R.R. TOLKIEN
# 30   Harry Potter and the Sorcerer's Stone (Harry P...        J. K. Rowling
# 32      The Two Towers (The Lord of the Rings, Part 2)       J.R.R. TOLKIEN
# 43                               To Kill a Mockingbird           Harper Lee
# ...

# %% [markdown]
# # Collaborative filtering based recommendation System

# %%
x=data.groupby('User-ID').count()['Book-Rating'] >200
#This operation uses the boolean Series (x) to filter itself. Pandas only keeps the rows where the value in the filter is True.
#Effect: It drops all the False values from the Series x

# %%
user_who_rated=x[x].index
user_who_rated
# Out:
# Index([   254,   2276,   2766,   2977,   3363,   3757,   4017,   4385,   6242,
#          6251,
#        ...
#        274004, 274061, 274301, 274308, 274808, 275970, 277427, 277478, 277639,
#        278418],
#       dtype='int64', name='User-ID', length=899)

# %%
filtered_rating=data[data['User-ID'].isin(user_who_rated)]

# %%
filtered_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1456      277427  002542730X           10
# 1457      277427  0026217457            0
# 1458      277427  003008685X            8
# 1459      277427  0030615321            0
# 1460      277427  0060002050            0
# ...          ...         ...          ...
# 1147612   275970  3829021860            0
# 1147613   275970  4770019572            0
# 1147614   275970   896086097            0
# 1147615   275970  9626340762            8
# 1147616   275970  9626344990            0
#
#                                                 Book-Title  \
# 1456     Politically Correct Bedtime Stories: Modern Ta...
# 1457                    Vegetarian Times Complete Cookbook
# 1458                                              Pioneers
# 1459      Ask for May, Settle for June (A Doonesbury book)
# 1460                     On a Wicked Dawn (Cynster Novels)
# ...                                                    ...
# ...

# %%
y=filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50

# %%
more_rated_books=y[y].index

# %%
more_rated_books
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        '84 Charing Cross Road', 'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Cry In The Night',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=742)

# %%
final_ratings=filtered_rating[filtered_rating['Book-Title'].isin(more_rated_books)]

# %%
final_ratings
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1456      277427  002542730X           10
# 1469      277427  0060930535            0
# 1471      277427  0060934417            0
# 1474      277427  0061009059            9
# 1480      277427  006440188X            0
# ...          ...         ...          ...
# 1147440   275970  1400031354            0
# 1147441   275970  1400031362            0
# 1147517   275970  1573229725            0
# 1147556   275970  1586210661            9
# 1147557   275970  1586212230            0
#
#                                                 Book-Title  \
# 1456     Politically Correct Bedtime Stories: Modern Ta...
# 1469                         The Poisonwood Bible: A Novel
# 1471                                    Bel Canto: A Novel
# 1474     One for the Money (Stephanie Plum Novels (Pape...
# 1480                                     The Secret Garden
# ...                                                    ...
# ...

# %%
table=final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
table
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
table.fillna(0,inplace=True)

# %%
table
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity_scores=cosine_similarity(table)

# %%
similarity_scores
# Out:
# array([[1.        , 0.09259251, 0.01122267, ..., 0.11132415, 0.06754227,
#         0.03967511],
#        [0.09259251, 1.        , 0.23225215, ..., 0.07313708, 0.16475569,
#         0.14009737],
#        [0.01122267, 0.23225215, 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.11132415, 0.07313708, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.06754227, 0.16475569, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.03967511, 0.14009737, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]], shape=(742, 742))

# %%
def recommend(book_name):
    index = np.where(table.index == book_name)[0][0]
    distances = similarity_scores[index]
    suggestions = sorted(list(enumerate(distances)), reverse=True, key=lambda x: x[1])[1:6]
    recommended_books = []
    for i in suggestions:
        item=[]
        temp_df=books[books['Book-Title']==table.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))

        recommended_books.append(item)
        
    return recommended_books

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['The Catcher in the Rye',
#   'J.D. Salinger',
#   'http://images.amazon.com/images/P/0316769487.01.MZZZZZZZ.jpg'],
#  ['Lord of the Flies',
#   'William Gerald Golding',
#   'http://images.amazon.com/images/P/0399501487.01.MZZZZZZZ.jpg'],
#  ["Slaughterhouse Five or the Children's Crusade: A Duty Dance With Death",
#   'Kurt Vonnegut',
#   'http://images.amazon.com/images/P/0440180295.01.MZZZZZZZ.jpg']]

# %%
import pickle
pickle.dump(pop_df,open('popular.pkl','wb'))

# %%
books.drop_duplicates('Book-Title')
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271354  0449906736      Flashpoints: Promise and Peril in a New World
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
pickle.dump(table, open('pt.pkl', 'wb'))
pickle.dump(books, open('books.pkl', 'wb'))
pickle.dump(similarity_scores, open('similarity_scores.pkl', 'wb'))
